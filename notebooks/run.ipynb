# %% [markdown]
# # iCELL - Cell Seeding & Dye Preparation
#
# Welcome to iCELL! This notebook calculates cell suspension volumes and generates preparation instructions.
#
# ## ⚙️ Setup (one-time)
#
# The supported setup is Docker only.
#
# From the repo root:
# ```bash
# bash scripts/start.sh
# ```
#
# Then open JupyterLab at `http://localhost:8888/lab?token=icell` and open this notebook there.
#
# ## 📋 Before You Run
#
# 1. **Edit `config/config.json`**
#    - Set `"mode": "no_dye"` or `"mode": "dye"`
#    - Update stock cell concentration if needed
#
# 2. **Create `data/input/` if needed, then prepare input files there**
#    - `cell_layout.csv` - required
#    - `dye_layout.csv` - only if using dye
#    - `meta_dye.csv` - only if using dye
#
# 3. **Run the cell below** to calculate volumes and generate instructions
#
# See [README.md](../README.md) for the supported Docker workflow.

# %%
# Setup environment and run pipeline
import sys
from pathlib import Path

# Add src to path so we can import icell modules
src_path = str(Path.cwd().parent / "src") if Path.cwd().name == "notebooks" else str(Path.cwd() / "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# Now we can import and run
from icell.pipeline import run_pipeline
results = run_pipeline()
# Out:
# ...
#   iCELL Pipeline: Cell Seeding & Dye Preparation
# ...
#
# 1. Loading configuration...
#    ✓ Mode: no_dye
#    ✓ Run name: cleo_seeding_density_test
#
# 2. Running calculations...
#    ✓ Configuration validated
#    ✓ Layouts loaded and merged
#    ✓ Cell suspension volumes calculated
#
# PREPARATION INSTRUCTIONS
# ------------------------
# RUN SUMMARY
# ...
# Run name: cleo_seeding_density_test
# Seeded wells: 96
# Wells: B2, B3, B4, B5, B8, B9, B10, B11, C2, C3, C4, C5, C8, C9, C10, C11, D2, D3, D4, D5, D8, D9, D10, D11, E2, E3, E4, E5, E8, E9, E10, E11, G2, G3, G4, G5, G8, G9, G10, G11, H2, H3, H4, H5, H8, H9, H10, H11, I2, I3, I4, I5, I8, I9, I10, I11, J2, J3, J4, J5, J8, J9, J10, J11, L2, L3, L4, L5, L8, L9, L10, L11, M2, M3, M4, M5, M8, M9, M10, M11, N2, N3, N4, N5, N8, N9, N10, N11, O2, O3, O4, O5, O8, O9, O10, O11
# Final well volume: 40.0 uL
# Dye enabled: False
# Cell suspension dispense per well: 40.0 uL
# Media dispense per well: 0.0 uL
#
# CELL SUSPENSION PREPARATION
# ...
